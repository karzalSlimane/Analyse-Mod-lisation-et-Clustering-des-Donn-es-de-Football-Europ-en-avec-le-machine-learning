# %%
import pandas as pd 
import sqlite3

# %%
""""establish connection with the database """
database = '../data/database.sqlite'
conn = sqlite3.connect(database)

# %%
"""Explore database tables"""
  
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)

# %%
"""Print out the tables in the database"""
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %%
"""
Explore each tables in the data base using 
using the pd.read_sql() 
"""
players = pd.read_sql("""SELECT * FROM Player;""",conn)

# %%
"""Display players table and their infos  """
players.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  11060 non-null  int64
#  1   player_api_id       11060 non-null  int64
#  2   player_name         11060 non-null  object
#  3   player_fifa_api_id  11060 non-null  int64
#  4   birthday            11060 non-null  object
#  5   height              11060 non-null  float64
#  6   weight              11060 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 605.0+ KB

# %%
countries = pd.read_sql("""SELECT * FROM  country ;""",conn)

# %%
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     int64
#  1   name    11 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 308.0+ bytes

# %%
teams = pd.read_sql("""SELECT * FROM Team;""",conn)

# %%
teams.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                299 non-null    int64
#  1   team_api_id       299 non-null    int64
#  2   team_fifa_api_id  288 non-null    float64
#  3   team_long_name    299 non-null    object
#  4   team_short_name   299 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
players_attrs = pd.read_sql("""SELECT * FROM Player_attributes ;""",conn)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 players_attrs = pd.read_sql("""SELECT * FROM Player_attributes ;""",conn)
#
# File ~/Music/Analyse-Mod-lisation-et-Clustering-des-Donn-es-de-Football-Europ-en-avec-le-machine-learning/ml_env/lib/python3.12/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
# ...

# %%
players_attrs.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
teams_attrs = pd.read_sql("""SELECT * FROM Team_attributes ;""",conn)

# %%
teams_attrs.head()
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
# ...

# %%
teams_attrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            489 non-null    float64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
# ...

# %%
matchs = pd.read_sql("""SELECT * FROM Match ; """, conn)

# %%
matchs = matchs.drop(columns=['B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','LBH','LBD','LBA','PSH','PSD','PSA','WHH','WHD','WHA','SJH','SJD','SJA','VCH','VCD','VCA','GBH','GBD','GBA','BSH','BSD','BSA'])

# %%
# Joindre Player_Attributes et Player
df_player_full = players_attrs.merge(players, how='left', on='player_api_id')

# %%
df_player_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 48 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id_x                  183978 non-null  int64
#  1   player_fifa_api_id_x  183978 non-null  int64
#  2   player_api_id         183978 non-null  int64
#  3   date                  183978 non-null  object
#  4   overall_rating        183142 non-null  float64
#  5   potential             183142 non-null  float64
#  6   preferred_foot        183142 non-null  object
#  7   attacking_work_rate   180748 non-null  object
#  8   defensive_work_rate   183142 non-null  object
#  9   crossing              183142 non-null  float64
#  10  finishing             183142 non-null  float64
#  11  heading_accuracy      183142 non-null  float64
#  12  short_passing         183142 non-null  float64
#  13  volleys               181265 non-null  float64
# ...

# %%
classicos = pd.read_sql("""SELECT Match.id, Match.possession,Match.goal,Match.shoton,Match.shotoff,Match.foulcommit,Match.corner,Match.cross,

       Country.name AS country_name, 
       
       League.name AS league_name, 
       
       season,stage, date,
       
       HT.team_long_name AS  home_team,
       
       AT.team_long_name AS away_team,
       
       home_team_goal, away_team_goal FROM Match
       
       JOIN Country on Country.id = Match.country_id
       
       JOIN League on League.id = Match.league_id
       
       LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
       
       LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
       
       ORDER by date;""", conn)

classicos
# Out:
#           id      possession  \
# 0      24559            None
# 1      24560            None
# 2      24561            None
# 3      24562            None
# 4      24613            None
# ...      ...             ...
# 25974  25945  <possession />
# 25975  25946  <possession />
# 25976  25947  <possession />
# 25977  25948  <possession />
# 25978  25949  <possession />
#
#                                                     goal      shoton  \
# 0                                                   None        None
# 1                                                   None        None
# 2                                                   None        None
# 3                                                   None        None
# 4                                                   None        None
# ...                                                  ...         ...
# 25974  <goal><value><comment>o</comment><stats><owngo...  <shoton />
# ...

# %%
classicos.head(2).to_csv('/home/karzal/SoutenanceProjet/class.csv')

# %%
# Create a function to calculate statistics for players
import re 
def aggregate_player_stats(match_data):
    player_stats = {}

    # Process each match
    for _, row in match_data.iterrows():
        # Parse scorers (goals) and assisters (assists)
        scorers = re.findall(r'<player1>(.*?)</player1>', str(row['goal']))
        assisters = re.findall(r'<player2>(.*?)</player2>', str(row['goal']))

        # Update goals for scorers
        for player in scorers:
            player_stats[player] = player_stats.get(player, {'goals': 0, 'assists': 0, 'shots': 0})
            player_stats[player]['goals'] += 1

        # Update assists for assisters
        for player in assisters:
            player_stats[player] = player_stats.get(player, {'goals': 0, 'assists': 0, 'shots': 0})
            player_stats[player]['assists'] += 1

        # Parse shots (if structured similarly to goals/assists)
        # Assume `shoton` contains <player1>...</player1> tags
        shot_players = re.findall(r'<player1>(.*?)</player1>', str(row['shoton']))
        for player in shot_players:
            player_stats[player] = player_stats.get(player, {'goals': 0, 'assists': 0, 'shots': 0})
            player_stats[player]['shots'] += 1

    # Convert to DataFrame
    stats_df = pd.DataFrame.from_dict(player_stats, orient='index')
    stats_df.index.name = 'player_api_id'
    stats_df.reset_index(inplace=True)
    return stats_df

# %%
player_stats = aggregate_player_stats(classicos)
player_stats['player_api_id'] = pd.to_numeric(player_stats['player_api_id'])

# %%
final_data = pd.merge(players, player_stats, on='player_api_id', how='left')
final_data.fillna(0, inplace=True)  # Fill missing stats with 0

# %%
final_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  goals  assists  shots
# 0      1992-02-29 00:00:00  182.88     187    0.0      0.0    0.0
# ...

# %%
final_data[final_data['player_name'] == 'Lionel Messi']
# Out:
#         id  player_api_id   player_name  player_fifa_api_id  \
# 6169  6176          30981  Lionel Messi              158023
#
#                  birthday  height  weight  goals  assists  shots
# 6169  1987-06-24 00:00:00  170.18     159  295.0     89.0  439.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate total contributions (goals + assists)
final_data['total_contributions'] = final_data['goals'] + final_data['assists']

# Get the top 10 players by total contributions
top_10_players = final_data.sort_values('total_contributions', ascending=False).head(10)

# Plotting
plt.figure(figsize=(12, 6))
plt.barh(top_10_players['player_name'], top_10_players['total_contributions'], color='skyblue')
plt.xlabel('Total Contributions (Goals + Assists)', fontsize=12)
plt.ylabel('Player Name', fontsize=12)
plt.title('Top 10 Players by Total Contributions', fontsize=16)
plt.gca().invert_yaxis()  # To show the highest scorer at the top
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Performance by season

# %%
seasons = classicos['season'].drop_duplicates() 
seasons.drop(columns=['season'])
season_dfs = {}
for season in seasons:
    season_dfs[season] = classicos[classicos['season'] == season]

# %%
# Apply the aggregate_player_stats function to each season's DataFrame
season_stats = {}
for season, match_data in season_dfs.items():
    season_stats[season] = aggregate_player_stats(match_data)

# %%
season_stats['2008/2009']
# Out:
#      player_api_id  goals  assists  shots
# 0            30872      5        1     11
# 1            32118      8        2      6
# 2            33101      9        0      5
# 3            39106      6        1     11
# 4            26181      6        2     19
# ...            ...    ...      ...    ...
# 1435         58294      1        0      0
# 1436        171796      0        1      1
# 1437         31938      0        0      1
# 1438         73845      0        0      1
# 1439         18784      1        0      0
#
# [1440 rows x 4 columns]

# %%
all_season_stats = pd.DataFrame()

# %%
for season, stats_df in season_stats.items():
    stats_df['season'] = season  # Add the season as a new column
    all_season_stats = pd.concat([all_season_stats, stats_df], ignore_index=True)
all_season_stats
# Out:
#       player_api_id  goals  assists  shots     season
# 0             30872      5        1     11  2008/2009
# 1             32118      8        2      6  2008/2009
# 2             33101      9        0      5  2008/2009
# 3             39106      6        1     11  2008/2009
# 4             26181      6        2     19  2008/2009
# ...             ...    ...      ...    ...        ...
# 14610        570830      1        0      0  2015/2016
# 14611        181211      1        0      0  2015/2016
# 14612         67349      1        0      0  2015/2016
# 14613         25843      1        0      0  2015/2016
# 14614        197757      1        0      0  2015/2016
#
# [14615 rows x 5 columns]

# %%
all_season_stats['player_api_id'] = pd.to_numeric(all_season_stats['player_api_id'], errors='coerce')

# %%
merged_data = pd.merge(players, all_season_stats, on='player_api_id', how='left')

# Fill missing values with 0
merged_data.fillna(0, inplace=True)

# %%
merged_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          2         155782      Aaron Cresswell              189615
# 3          3         162549          Aaron Doran              186170
# 4          4          30572        Aaron Galindo              140161
# ...      ...            ...                  ...                 ...
# 20154  11073          36491            Zsolt Low              111191
# 20155  11074          35506  Zurab Khizanishvili               47058
# 20156  11075          39902   Zvjezdan Misimovic              102359
# 20157  11075          39902   Zvjezdan Misimovic              102359
# 20158  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  goals  assists  shots     season
# ...

# %%
merged_data= merged_data[merged_data['season'] != 0]

# %%
merged_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 1          2         155782      Aaron Cresswell              189615
# 2          2         155782      Aaron Cresswell              189615
# 5          5          23780         Aaron Hughes               17725
# 6          5          23780         Aaron Hughes               17725
# 7          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 20153  11072         111182         Zsolt Laczko              164680
# 20155  11074          35506  Zurab Khizanishvili               47058
# 20156  11075          39902   Zvjezdan Misimovic              102359
# 20157  11075          39902   Zvjezdan Misimovic              102359
# 20158  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  goals  assists  shots     season
# ...

# %%
merged_data['contributions'] = merged_data['assists']+merged_data['goals']
# Out:
# /tmp/ipykernel_71066/1072149994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['contributions'] = merged_data['assists']+merged_data['goals']

# %%
merged_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 1          2         155782      Aaron Cresswell              189615
# 2          2         155782      Aaron Cresswell              189615
# 5          5          23780         Aaron Hughes               17725
# 6          5          23780         Aaron Hughes               17725
# 7          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 20153  11072         111182         Zsolt Laczko              164680
# 20155  11074          35506  Zurab Khizanishvili               47058
# 20156  11075          39902   Zvjezdan Misimovic              102359
# 20157  11075          39902   Zvjezdan Misimovic              102359
# 20158  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  goals  assists  shots     season  \
# ...

# %%
top_20_cont = merged_data.sort_values(['season','contributions'], ascending=[True,False])

# %%
text='2008/2009'
int(text.split("/")[0])
# Out:
# 2008

# %%
top_20_cont['season']=top_20_cont['season'].apply(lambda x : int(x.split('/')[0]))

# %%
top_20_cont
# Out:
#           id  player_api_id         player_name  player_fifa_api_id  \
# 4854    2625          38460        Diego Forlan               49072
# 17169   9445          33639        Samuel Eto'o                9676
# 4512    2430          30909         David Villa              113422
# 7279    3936          25759     Gonzalo Higuain              167664
# 11296   6176          30981        Lionel Messi              158023
# ...      ...            ...                 ...                 ...
# 19912  10936         210452         Yoann Court              199419
# 19980  10971         320672        Younes Namli              226539
# 20011  10986          71502     Youssuf Mulumbu              179544
# 20032  10997          98254       Yuto Nagatomo              194359
# 20080  11030          25772  Zdravko Kuzmanovic              168650
#
#                   birthday  height  weight  goals  assists  shots  season  \
# 4854   1979-05-19 00:00:00  180.34     172   32.0      7.0   32.0    2008
# ...

# %%
top_20_cont[top_20_cont['player_name']=='David Villa']
# Out:
#         id  player_api_id  player_name  player_fifa_api_id  \
# 4512  2430          30909  David Villa              113422
# 4513  2430          30909  David Villa              113422
# 4514  2430          30909  David Villa              113422
# 4515  2430          30909  David Villa              113422
# 4516  2430          30909  David Villa              113422
# 4517  2430          30909  David Villa              113422
#
#                  birthday  height  weight  goals  assists  shots     season  \
# 4512  1981-12-03 00:00:00  175.26     152   30.0      5.0   55.0  2008/2009
# 4513  1981-12-03 00:00:00  175.26     152   22.0      3.0   59.0  2009/2010
# 4514  1981-12-03 00:00:00  175.26     152   18.0      8.0   55.0  2010/2011
# 4515  1981-12-03 00:00:00  175.26     152    5.0      1.0   13.0  2011/2012
# 4516  1981-12-03 00:00:00  175.26     152   10.0      0.0    0.0  2012/2013
# 4517  1981-12-03 00:00:00  175.26     152   14.0      1.0    0.0  2013/2014
#
# ...

# %%
liste=(top_20_cont['player_name'].unique())

# %%
plt.figure(figsize=(15, 8))
for player in liste[12:20] : 
    df_filtred=top_20_cont[top_20_cont['player_name']==player].sort_values(by='season' , ascending=True)
    plt.plot(df_filtred['season'] , df_filtred['contributions'] , marker='o' , label=player)
plt.legend(title='player_name' , bbox_to_anchor=(1,1))
plt.show()

# %%
df = top_20_cont

# %%
import seaborn as sns
# 1. Top Scorers per Season
plt.figure(figsize=(12, 6))
sns.barplot(x="season", y="goals", hue="player_name", data=df)
plt.title("Top Scorers per Season")
plt.xticks(rotation=45)
plt.ylabel("Goals")
plt.xlabel("Season")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# 2. Goals vs. Assists
plt.figure(figsize=(8, 6))
sns.scatterplot(x="goals", y="assists", hue="player_name", style="season", data=df)
plt.title("Goals vs Assists")
plt.xlabel("Goals")
plt.ylabel("Assists")
plt.show()

# 3. Contributions Over Seasons
plt.figure(figsize=(12, 6))
sns.lineplot(x="season", y="contributions", hue="player_name", data=df, marker="o")
plt.title("Player Contributions Over Seasons")
plt.xticks(rotation=45)
plt.ylabel("Contributions")
plt.xlabel("Season")
plt.show()

# 4. Shots vs Contributions
plt.figure(figsize=(8, 6))
sns.scatterplot(x="shots", y="contributions", hue="player_name", data=df)
plt.title("Shots vs Contributions")
plt.xlabel("Shots")
plt.ylabel("Contributions")
plt.show()

# 5. Height vs Weight
plt.figure(figsize=(8, 6))
sns.scatterplot(x="height", y="weight", hue="player_name", data=df, size="contributions", sizes=(50, 500))
plt.title("Height vs Weight of Players")
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Music/Analyse-Mod-lisation-et-Clustering-des-Donn-es-de-Football-Europ-en-avec-le-machine-learning/ml_env/lib/python3.12/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/Music/Analyse-Mod-lisation-et-Clustering-des-Donn-es-de-Football-Europ-en-avec-le-machine-learning/ml_env/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select the top 10 players based on total contributions
top_contributors = final_data.sort_values(by="total_contributions", ascending=False).head(10)

# Prepare data for the radar chart
attributes = ['goals', 'assists', 'shots', 'total_contributions']
num_vars = len(attributes)

# Function to create radar chart
def create_radar_chart(data, attributes, title):
    # Create angles for the radar chart
    angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
    angles += angles[:1]

    # Initialize the radar chart
    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

    for _, row in data.iterrows():
        values = row[attributes].tolist()
        values += values[:1]  # Repeat the first value to close the circle
        ax.plot(angles, values, label=row['player_name'], linewidth=2)
        ax.fill(angles, values, alpha=0.25)

    # Add attributes as labels around the chart
    ax.set_yticks([])
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(attributes, fontsize=12)
    ax.set_title(title, fontsize=16, y=1.1)
    ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))

    plt.show()

# Create the radar chart for top 10 contributors
create_radar_chart(top_contributors, attributes, "Top 10 Players by Total Contributions")

# %%
# Assuming `player_df` is the Player table and `player_attributes_df` is the Player_Attributes table
merged_players = pd.merge(players, players_attrs, on="player_api_id", how="inner")

# Display the mermerged_players.head()

# %%
merged_players = merged_players[['player_api_id', 'player_name',
       'birthday', 'height', 'weight',  'date',
       'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
       'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
       'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
       'gk_reflexes']]

# %%
merged_players
# Out:
#         player_api_id         player_name             birthday  height  \
# 0              505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88
# 1              505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88
# 2              505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88
# 3              505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88
# 4              505942  Aaron Appindangoye  1992-02-29 00:00:00  182.88
# ...               ...                 ...                  ...     ...
# 183973          39902  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
# 183974          39902  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
# 183975          39902  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
# 183976          39902  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
# 183977          39902  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
#
#         weight                 date  overall_rating  potential preferred_foot  \
# ...

# %%
final_merged_df = pd.merge(merged_players, merged_data, on="player_api_id", how="inner")

# %%
final_merged_df
# Out:
#         player_api_id       player_name_x           birthday_x  height_x  \
# 0              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 1              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 2              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 3              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 4              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# ...               ...                 ...                  ...       ...
# 345449          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345450          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345451          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345452          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345453          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
#
#         weight_x                 date  overall_rating  potential  \
# ...

# %%
final_merged_df.columns
# Out:
# Index(['player_api_id', 'player_name_x', 'birthday_x', 'height_x', 'weight_x',
#        'date', 'overall_rating', 'potential', 'preferred_foot',
#        'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'id', 'player_name_y',
#        'player_fifa_api_id', 'birthday_y', 'height_y', 'weight_y', 'goals',
#        'assists', 'shots', 'season', 'contributions'],
#       dtype='object')

# %%
final_merged_df = final_merged_df[['player_api_id', 'player_name_x', 'birthday_x', 'height_x', 'weight_x',
       'date', 'overall_rating', 'potential', 'preferred_foot',
       'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing',
       'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
       'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
       'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
       'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'marking',
       'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
       'gk_kicking', 'gk_positioning', 'gk_reflexes',
       'player_fifa_api_id', 'goals',
       'assists', 'shots', 'season', 'contributions']]

# %%
final_merged_df
# Out:
#         player_api_id       player_name_x           birthday_x  height_x  \
# 0              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 1              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 2              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 3              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# 4              155782     Aaron Cresswell  1989-12-15 00:00:00    170.18
# ...               ...                 ...                  ...       ...
# 345449          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345450          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345451          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345452          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
# 345453          39902  Zvjezdan Misimovic  1982-06-05 00:00:00    180.34
#
#         weight_x                 date  overall_rating  potential  \
# ...
